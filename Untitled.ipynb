# %%
import urllib
import urllib.parse
from bs4 import BeautifulSoup


titleList = []

plusUrl = urllib.parse.quote_plus(input("검색어를 입력하세요"))
end = input("몇 페이지까지 읽으시겠습니까?")

page = 1
count = 1

while (count != int(end)+1):
    url = f'https://search.naver.com/search.naver?&where=news&query={plusUrl}&sm=tab_pge&sort=0&photo=0&field=0&reporter_article=&pd=0&ds=&de=&docid=&nso=so:r,p:all,a:all&mynews=0&cluster_rank=70&start={page}'
    html = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(html, 'html.parser')
    
    title = soup.find_all(class_= '_sp_each_title')
    
    print(f'----------{count}페이지의 결과 입니다')
    
    for i in title:
        print(i.attrs['title'])
        titleList.append(i.attrs['title']+'\n')
    print()
    
    page += 10
    count += 1
# Out:
# 검색어를 입력하세요 나현호
# 몇 페이지까지 읽으시겠습니까? 200
# ----------1페이지의 결과 입니다
# 장애인·이주여성 부부의 죽음이 더 안타까운 이유
# 광주 민간공원 비리 사실로...이용섭 시장 동생까지 연루
# 5월 단체, 옛 광주교도소 발굴 유골 수사 의뢰
# '미사일 쏜 듯' 폭발 사고 광양제철소 합동 감식
# 광주 모텔 방화 추정 화재..."2명 사망·31명 부상"
# 광주 모텔 '방화 날벼락'...33명 사상
# 옛 광주교도소에서 유골 40여 구 발굴
# 광주 모텔 화재 1명 사망·32명 부상...방화범 자백
# 이순신대교 트레일러 컨테이너 바다로 추락
# 광주 모텔 방화 30대 영장...'횡설수설'
#
# ----------2페이지의 결과 입니다
# 광주 모텔 방화범 '횡설수설'...2명 사망·31명 부상
# 민간 공원 비리 이용섭 시장 사과 촉구 잇따라
# 재개발 건설사 선정 앞두고...돈 봉투 건네는 현장 '포착'
# [단독] 광주 재개발 비리...포스코 금품 살포 장면 '포착'
# 3번이나 찾아가 호소했지만...범행 못 막은 경찰
# 여성 쫓아와 "재워달라"...집 침입 시도한 30대 징역 4년
# '골프·군사 반란 오찬' 전두환 재판 불출석 '공방'
# [취재N팩트] '전두환 멀쩡한데?'..."불출석 허가 취소하라"
# 전두환, 또 재판 안 나와...5·18 헬기 사격 공방
# 실종 제주 고등학생 사흘 만에 숨진 채 발견
#
# ----------3페이지의 결과 입니다
# 흔들고 던지고...'생후 25일 아기' 학대한 산후도우미
# 광주세계수영대회 여자 선수 '몰카' 일본인 입건
# 여중생 딸 살해 친모·의붓아버지 징역 30년 선고
# "잘못했어요"...애원에도 여중생 무차별 폭행 파문
# 대형건설사, 재개발 조합장도 입맛대로 교체?
# 경찰, 남편 둔기 살해 60대 구속영장 신청
# 태풍 목포 통과...피해 신고만 3백 건
# "약탈문화재 함께 찾는다"...한-아세안 문화장관 협력 강화
# ...

# %%
f= open('devdog.txt', 'w', encoding = 'utf-8')
for i in titleList:
    f.write(i)
f.close()
